# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("bsaseq_results.smooth.tsv", sep="\t", comment="#")
print(df.columns)
chrom1_df = df[df["CHROM"] == "Cp4.1LG01"]
# 1. Plot the first line and capture the axis (ax)
ax = chrom1_df.plot(x='POS', y='Gstat', label='Gstat')

# 2. Plot the second line on the same axis with a dashed style
chrom1_df.plot(x='POS', y='Opt1_MaxNoChr0_Gstat_a0.05', ax=ax, linestyle='--', label='Line 2')
chrom1_df.plot(x='POS', y='Opt1_MaxNoChr0_Gstat_a0.01', ax=ax, linestyle='--', label='0.01')

plt.ylabel('Value')
plt.show()
# chrom1_df = df[df["CHROM"] == "Cp4.1LG01"]
# print(chrom1_df.columns)
# chrom1_df.plot(x='POS', y='Gstat', title='BBLogBF for Cp4.1LG01')
# chrom1_df.plot(x='POS', y='Opt1_MaxNoChr0_Gstat_a0.05',)
# plt.show()
# Out:
# Index(['CHROM', 'POS', 'DeltaSI', 'Gstat', 'ED', 'LOD', 'BBLogBF', 'NumSNPs',
#        'MeanHighDP', 'MeanLowDP', 'Opt1_MaxNoChr0_DeltaSI_a0.05',
#        'Opt1_MaxNoChr0_Gstat_a0.05', 'Opt1_MaxNoChr0_ED_a0.05',
#        'Opt1_MaxNoChr0_LOD_a0.05', 'Opt1_MaxNoChr0_BBLogBF_a0.05',
#        'Opt2_MaxPerChr_DeltaSI_a0.05', 'Opt2_MaxPerChr_Gstat_a0.05',
#        'Opt2_MaxPerChr_ED_a0.05', 'Opt2_MaxPerChr_LOD_a0.05',
#        'Opt2_MaxPerChr_BBLogBF_a0.05', 'Opt3_DepthCI_DeltaSI_a0.05',
#        'Opt3_DepthCI_Gstat_a0.05', 'Opt3_DepthCI_ED_a0.05',
#        'Opt3_DepthCI_LOD_a0.05', 'Opt3_DepthCI_BBLogBF_a0.05',
#        'Opt4_FDR_DeltaSI_a0.05', 'Opt4_FDR_Gstat_a0.05', 'Opt4_FDR_ED_a0.05',
#        'Opt4_FDR_LOD_a0.05', 'Opt4_FDR_BBLogBF_a0.05',
#        'Opt5_ZScore_DeltaSI_a0.05', 'Opt5_ZScore_Gstat_a0.05',
#        'Opt5_ZScore_ED_a0.05', 'Opt5_ZScore_LOD_a0.05',
#        'Opt5_ZScore_BBLogBF_a0.05', 'Opt1_MaxNoChr0_DeltaSI_a0.01',
#        'Opt1_MaxNoChr0_Gstat_a0.01', 'Opt1_MaxNoChr0_ED_a0.01',
#        'Opt1_MaxNoChr0_LOD_a0.01', 'Opt1_MaxNoChr0_BBLogBF_a0.01',
#        'Opt2_MaxPerChr_DeltaSI_a0.01', 'Opt2_MaxPerChr_Gstat_a0.01',
#        'Opt2_MaxPerChr_ED_a0.01', 'Opt2_MaxPerChr_LOD_a0.01',
#        'Opt2_MaxPerChr_BBLogBF_a0.01', 'Opt3_DepthCI_DeltaSI_a0.01',
#        'Opt3_DepthCI_Gstat_a0.01', 'Opt3_DepthCI_ED_a0.01',
#        'Opt3_DepthCI_LOD_a0.01', 'Opt3_DepthCI_BBLogBF_a0.01',
#        'Opt4_FDR_DeltaSI_a0.01', 'Opt4_FDR_Gstat_a0.01', 'Opt4_FDR_ED_a0.01',
#        'Opt4_FDR_LOD_a0.01', 'Opt4_FDR_BBLogBF_a0.01',
#        'Opt5_ZScore_DeltaSI_a0.01', 'Opt5_ZScore_Gstat_a0.01',
#        'Opt5_ZScore_ED_a0.01', 'Opt5_ZScore_LOD_a0.01',
#        'Opt5_ZScore_BBLogBF_a0.01'],
#       dtype='str')
